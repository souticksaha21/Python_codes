# %%
#This notebook shows different plotting techniques using matplotlib package in python

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import imageio
import os

# %%
x=[1,2,4,5,2,5,2,5,7]
y=[2,3,5,3,4,4,5,6,7]
z=[n**2 for n in x]
#x and y are x and y coordinates, z is size, 'green is color'
plt.scatter(x, y, z, 'green')
plt.show()

# %%
#colors can also be represented by numbers
x=[1,2,4,5,2,5,2,5,7]
y=[2,3,5,3,4,4,5,6,7]
z=[n**2 for n in x]
sc=plt.scatter(x, y, z, z)
plt.colorbar(sc)
plt.show()

# %%
#x,ylabel,title
x=[1,2,4,5,2,5,2,5,7]
y=[2,3,5,3,4,4,5,6,7]
z=[n**2 for n in x]
plt.scatter(x, y, z, z)
plt.xlabel("x")
plt.ylabel("y")
plt.title("y vs. x")
plt.show()

# %%
#x,ylabel,title, font size
x=[1,2,4,5,2,5,2,5,7]
y=[2,3,5,3,4,4,5,6,7]
z=[n**2 for n in x]
plt.scatter(x, y, z, z)
plt.xlabel("x")
plt.ylabel("y")
plt.title("y vs. x")
plt.rc('font', size=10)
plt.show()

# %%
#x,ylabel,title, font size
x=[1,2,4,5,2,5,2,5,7]
y=[2,3,5,3,4,4,5,6,7]
z=[n**2 for n in x]
plt.scatter(x, y, z, z)
plt.xlabel("x")
plt.ylabel("y")
plt.title("y vs. x")
plt.rc('font', size=5)
plt.show()

# %%
#saving figure
x=[1,2,4,5,2,5,2,5,7]
y=[2,3,5,3,4,4,5,6,7]
z=[n**2 for n in x]
plt.scatter(x, y, z, z)
plt.xlabel("x")
plt.ylabel("y")
plt.title("y vs. x")
plt.rc('font', size=15)
plt.savefig("test.png")
plt.show()

# %%
#Different fontsize for different elements
x=[1,2,4,5,2,5,2,5,7]
y=[2,3,5,3,4,4,5,6,7]
z=[n**2 for n in x]
plt.scatter(x, y, z, z)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20)
plt.show()

# %%
#grid on
x=[1,2,4,5,2,5,2,5,7]
y=[2,3,5,3,4,4,5,6,7]
z=[n**2 for n in x]
plt.scatter(x, y, z, z)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20)
plt.grid()
plt.show()

# %%
#x and y ticks 
x=[1,2,4,5,2,5,2,5,7]
y=[2,3,5,3,4,4,5,6,7]
z=[n**2 for n in x]
plt.scatter(x, y, z, z)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20)
plt.grid()
plt.xticks([1,3,5,7], fontsize=10)
plt.yticks([2,4,6], fontsize=20)
plt.show()

# %%
#x and y ticklabels
x=[1,2,4,5,2,5,2,5,7]
y=[2,3,5,3,4,4,5,6,7]
z=[n**2 for n in x]
plt.scatter(x, y, z, z)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20)
plt.grid()
plt.xticks([1,3,5,7], fontsize=10)
plt.yticks([2,4,6],["low","medium","high"],fontsize=20)
plt.show()

# %%
#new plotstyles
z1=[1,2,3,4,5]
z=[n**2 for n in z1]
plt.plot(z1, z,'go-')
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20)
plt.grid()
plt.show()

# %%
#new plotstyles: markerfacecolor and markersize
z1=[1,2,3,4,5]
z=[n**2 for n in z1]
plt.plot(z1, z,'o-', markersize=8, markerfacecolor='r')
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20)
plt.grid()
plt.show()

# %%
#new plotstyles markeredgecolor
z1=[1,2,3,4,5]
z=[n**2 for n in z1]
plt.plot(z1, z,'o-', markersize=12, markerfacecolor='r',markeredgewidth=2,  markeredgecolor='k')
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20)
plt.grid()
plt.show()

# %%
#new plotstyles linewidth and linecolor
z1=[1,2,3,4,5]
z=[n**2 for n in z1]
plt.plot(z1, z,'mo-', markersize=12, markerfacecolor='r',markeredgewidth=2,  markeredgecolor='k',linewidth=2)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20)
plt.grid()
plt.show()

# %%
#creating your own color
c1=[0.65, 0, 0.25] #new color 1
c2=[1, 0.5, 0.5] #new color 2
z1=[1,2,3,4,5]
z=[n**2 for n in z1]
plt.plot(z1, z,'mo-', markersize=12, markerfacecolor=c1,markeredgewidth=2,  markeredgecolor=c2, linewidth=2)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20)
plt.grid()
plt.show()

# %%
#Setting axes to log scale 
c1=[0.65, 0, 0.25] #new color 1
c2=[1, 0.5, 0.5] #new color 2
z1=[1,2,3,4,5]
z=[n**2 for n in z1]
plt.plot(z1, z,'mo-', markersize=12, markerfacecolor=c1,markeredgewidth=2,  markeredgecolor=c2, linewidth=2)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20)
plt.yscale('log')
plt.grid()
plt.show()

# %%
#Setting axes  limits 
c1=[0.65, 0, 0.25] #new color 1
c2=[1, 0.5, 0.5] #new color 2
z1=[1,2,3,4,5]
z=[n**2 for n in z1]
plt.plot(z1, z,'mo-', markersize=12, markerfacecolor=c1,markeredgewidth=2,  markeredgecolor=c2, linewidth=2)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20)
plt.yscale('log')
plt.grid()
plt.xlim([2,4]) #x limit
plt.show()

# %%
#Setting title font to bold
c1=[0.65, 0, 0.25] #new color 1
c2=[1, 0.5, 0.5] #new color 2
z1=[1,2,3,4,5]
z=[n**2 for n in z1]
plt.plot(z1, z,'mo-', markersize=12, markerfacecolor=c1,markeredgewidth=2,  markeredgecolor=c2, linewidth=2)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20, fontweight='bold')
plt.yscale('log')
plt.grid()
plt.show()

# %%
#Setting axes line width
c1=[0.65, 0, 0.25] #new color 1
c2=[1, 0.5, 0.5] #new color 2
z1=[1,2,3,4,5]
z=[n**2 for n in z1]
plt.plot(z1, z,'mo-', markersize=12, markerfacecolor=c1,markeredgewidth=2,  markeredgecolor=c2, linewidth=2)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20, fontweight='bold')
ax = plt.gca()
for axis in ['top','bottom','left','right']:
  ax.spines[axis].set_linewidth(3)
plt.grid()
plt.show()

# %%
#Setting legends
c1=[0.65, 0, 0.25] #new color 1
c2=[1, 0.5, 0.5] #new color 2
z1=[1,2,3,4,5]
z=[n**2 for n in z1]
z2=[n**3 for n in z1]
plt.plot(z1, z,'mo-', markersize=12, markerfacecolor=c1,markeredgewidth=2,  markeredgecolor=c2, linewidth=2)
plt.plot(z1, z2,'cs-', markersize=12, markerfacecolor='g',markeredgewidth=2,  markeredgecolor='k', linewidth=2)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20, fontweight='bold')
ax = plt.gca()
for axis in ['top','bottom','left','right']:
  ax.spines[axis].set_linewidth(3)
plt.yscale('log')
plt.legend(['y=x^2','y=x^3'])
plt.grid()
plt.show()

# %%
#Setting legends location
c1=[0.65, 0, 0.25] #new color 1
c2=[1, 0.5, 0.5] #new color 2
z1=[1,2,3,4,5]
z=[n**2 for n in z1]
z2=[n**3 for n in z1]
plt.plot(z1, z,'mo-', markersize=12, markerfacecolor=c1,markeredgewidth=2,  markeredgecolor=c2, linewidth=2)
plt.plot(z1, z2,'cs-', markersize=12, markerfacecolor='g',markeredgewidth=2,  markeredgecolor='k', linewidth=2)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=15)
plt.title("y vs. x", fontsize=20, fontweight='bold')
ax = plt.gca()
for axis in ['top','bottom','left','right']:
  ax.spines[axis].set_linewidth(3)
plt.yscale('log')
plt.legend(['y=x^2','y=x^3'], loc='lower right')
plt.grid()
plt.show()

# %%
#Histogram
x1=[1,2,3,1,3,2,1,2,3,2,2,3,2,2,3,2,4,2,4,2,2,2,2,4,3,2,2]
plt.hist(x)
plt.show()

# %%
#Histogram with details
x1=[1,2,3,1,3,2,1,2,3,2,2,3,2,2,3,2,4,2,4,2,2,2,2,4,3,2,2]
#data,number of bins,facecolor
plt.hist(x,3,facecolor='red')
plt.show()

# %%
#Histogram with details
x1=[1,2,3,1,3,2,1,2,3,2,2,3,2,2,3,2,4,2,4,2,2,2,2,4,3,2,2]
#data,number of bins,facecolor
plt.hist(x,3,facecolor='red',edgecolor='k',linewidth=3)
plt.show()

# %%
#Errorbars
x = np.linspace(0, 10, 50) #50 x points equally spaced
dy = 0.8 #maximum error/2
y = np.sin(x) + dy * np.random.randn(50) #defining y values

plt.errorbar(x, y, yerr=dy, fmt='.k');

# %%
#Errorbars
x = np.linspace(0, 10, 50) #50 x points equally spaced
dy = 0.8 #maximum error/2
y = np.sin(x) + dy * np.random.randn(50) #defining y values

plt.plot(x, y,'mo-', markersize=6, markerfacecolor=c1,markeredgewidth=1,  markeredgecolor=c2, linewidth=2)
plt.errorbar(x, y, yerr=dy, fmt='k');

# %%
#plotting multiple lines in a loop
x=[[1,2,3,4,5,6],[3,4,5,2,5,6],[2,3,4,3,4,6]]
y=[[1,2,3,2,3,4],[2,3,4,5,3,4],[2,5,6,7,5,4]]
for k in range(len(y)):
    c2=[k/3, 0, 0] #random colors
    plt.plot(x[k],y[k],color=c2,linewidth=3)

# %%
np.random.seed(19680801)
data = np.random.random((50, 50, 50))

fig, ax = plt.subplots()

for i in range(len(data)):
    ax.cla()
    ax.imshow(data[i])
    ax.set_title("frame {}".format(i))
    # Note that using time.sleep does *not* work here!
    #plt.pause(0.1)

# %%
len(data)
# Out:
# 50

# %%
#The three commands below help making animations.
y = np.random.randint(30, 40, size=(40))
plt.plot(y)
plt.ylim(20,50)
# Out:
# (20.0, 50.0)

# %%
## ONE ##
plt.plot(y[:-3])
plt.ylim(20,50)
plt.savefig('1.png')
plt.show()
## TWO ##
plt.plot(y[:-2])
plt.ylim(20,50)
plt.savefig('2.png')
plt.show()
## THREE ##
plt.plot(y[:-1])
plt.ylim(20,50)
plt.savefig('3.png')
plt.show()
## FOUR ##
plt.plot(y)
plt.ylim(20,50)
plt.savefig('4.png')
plt.show()

# %%
# Build GIF
with imageio.get_writer('mygif.gif', mode='I') as writer:
    for filename in ['1.png', '2.png', '3.png', '4.png']:
        image = imageio.imread(filename)
        writer.append_data(image)

# %%
#We will write a code in loop for animation : Individual pictures are saved as i.png where i runs from 1 to N
#Errorbars
x = np.linspace(0, 10, 50) #50 x points equally spaced
dy = 0.8 #maximum error/2
fname=[] #list of filenames
for i in range(10):
    y = np.sin(x) + dy * np.random.randn(50)
    plt.plot(x, y,'mo-', markersize=6, markerfacecolor=c1,markeredgewidth=1,  markeredgecolor=c2, linewidth=2)
    plt.errorbar(x, y, yerr=dy, fmt='k');
    plt.grid()
    plt.savefig(str(i+1)+'.png')
    fname.append(str(i+1)+'.png')
    
with imageio.get_writer('mygif2.gif', mode='I') as writer:
    for filename in fname:
        image = imageio.imread(filename)
        writer.append_data(image)
